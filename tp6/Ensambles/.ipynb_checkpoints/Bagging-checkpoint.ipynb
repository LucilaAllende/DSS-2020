# %% [markdown]
# # Método de Ensable Bagging

# %% [markdown]
# ### 1. Realizamos las importaciones necesarias

# %%
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import classification_report
from sklearn.datasets import load_breast_cancer
from numpy import mean
from numpy import std
import pandas as pd

# %% [markdown]
# ### 2. Cargamos el dataset de cancer propio de sklearn

# %%
cancer = load_breast_cancer()
X = pd.DataFrame(cancer.data, columns = cancer["feature_names"])
y = cancer["target"]

# %% [markdown]
# ### 3. Dividimos el dataset en un conjunto de datos para entrenar y otro para probar

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,  test_size=0.3, random_state = 109)

# %% [markdown]
# ### 4. Creamos el modelo Bagging y lo entrenamos

# %%
rfc = RandomForestClassifier(random_state = 0)
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %% [markdown]
# ### 5. Evaluamos el modelo con validacion cruzada

# %%
# definir el método de evaluación
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# evaluar el modelo en el conjunto de datos de prueba
n_scores = cross_val_score(rfc, X_test, y_test, scoring='accuracy', cv=cv, n_jobs=-1)
# informe de rendimiento
print('Promedio de Exactitud: %.3f Desviacion Estandar => %.3f' % (mean(n_scores), std(n_scores)))
# Out:
# Promedio de Exactitud: 0.945 Desviacion Estandar => 0.057

# %% [markdown]
# ### 6. Mostramos informacion sobre como predice el modelo

# %%
predictions = rfc.predict(X_test)

print("Informe de clasificación")
print(classification_report(y_test, predictions))
# Out:
# Informe de clasificación
#               precision    recall  f1-score   support
#
#            0       1.00      0.94      0.97        63
#            1       0.96      1.00      0.98       108
#
#     accuracy                           0.98       171
#    macro avg       0.98      0.97      0.97       171
# weighted avg       0.98      0.98      0.98       171

# %% [markdown]
# ### 7. Realizamos predicciones

# %% [markdown]
# #### a. Creamos un dataframe que contenga todos los datos con todas las columnas.

# %%
df = X
df['b/m'] = cancer["target"]
df
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %% [markdown]
# #### b. Seleccionamos 5 filas del conjunto de datos de prueba

# %%
row = X_test.head(5)
row
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 531        11.67         20.02           75.21      416.2          0.10160
# 52         11.94         18.24           75.71      437.6          0.08261
# 280        19.16         26.60          126.20     1138.0          0.10200
# 256        19.55         28.77          133.60     1207.0          0.09260
# 204        12.47         18.60           81.09      481.9          0.09965
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 531           0.09453         0.04200              0.02157         0.1859
# 52            0.04751         0.01972              0.01349         0.1868
# 280           0.14530         0.19210              0.09664         0.1902
# 256           0.20630         0.17840              0.11440         0.1893
# 204           0.10580         0.08005              0.03821         0.1925
#
#      mean fractal dimension  ...  worst radius  worst texture  \
# ...

# %% [markdown]
# #### c. Realizamos la predeccion de esas filas

# %%
yhat = rfc.predict(row)
for prediccion in yhat:
    print('Prediccion: %d' % prediccion)
# Out:
# Prediccion: 1
# Prediccion: 1
# Prediccion: 0
# Prediccion: 0
# Prediccion: 1

# %% [markdown]
# #### d. Comprobamos si la prediccion es correcta, usando el dataframe creado anteriormente.

# %%
df.iloc[[531,52, 280, 256, 204]]
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 531        11.67         20.02           75.21      416.2          0.10160
# 52         11.94         18.24           75.71      437.6          0.08261
# 280        19.16         26.60          126.20     1138.0          0.10200
# 256        19.55         28.77          133.60     1207.0          0.09260
# 204        12.47         18.60           81.09      481.9          0.09965
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 531           0.09453         0.04200              0.02157         0.1859
# 52            0.04751         0.01972              0.01349         0.1868
# 280           0.14530         0.19210              0.09664         0.1902
# 256           0.20630         0.17840              0.11440         0.1893
# 204           0.10580         0.08005              0.03821         0.1925
#
# ...

# %% [markdown]
# Se observa que en este caso, predijo correctamente las 5 filas que se le proporciono.
