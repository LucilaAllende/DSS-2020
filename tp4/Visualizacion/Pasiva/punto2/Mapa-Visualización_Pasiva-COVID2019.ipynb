# %% [markdown]
# # Mapa de Argentina covid-2019

# %% [markdown]
# ### 1. Tomo los datos del csv generado en el tp3 y saco los que no se necesitan.

# %%
import folium
import pandas as pd

# %%
# Borro las columnas que no me sirven

datos = pd.read_csv('innerjoins.csv')
df = pd.DataFrame(datos)
df.drop(['code','name','pop_dens','country_percentage','dia_inicio','dia_cuarentena','ciudad','transmision_tipo','informe_tipo','fuente'], axis='columns', inplace=True)
df
# Out:
#       total_pop       fecha         provincia  tot_casosconf  nue_casosconf  \
# 0      13827203   5/03/2020      Buenos Aires              2              1
# 1      13827203   8/03/2020      Buenos Aires             10              8
# 2      13827203  10/03/2020      Buenos Aires             20              1
# 3      13827203  11/03/2020      Buenos Aires             22              1
# 4      13827203  13/03/2020      Buenos Aires             34              1
# ...         ...         ...               ...            ...            ...
# 1891     127205   6/07/2020  Tierra del Fuego          80447              0
# 1892     127205   7/07/2020  Tierra del Fuego          83426              0
# 1893     127205   8/07/2020  Tierra del Fuego          87029              0
# 1894     127205   9/07/2020  Tierra del Fuego          90692              1
# 1895     127205  10/07/2020  Tierra del Fuego          94058              0
#
#       tot_fallecidos
# 0                  2
# ...

# %% [markdown]
# ### 2. Calculo la penetracion de casos  y la agrego al dataframe.

# %%
casos_cada_100_mil = []
casos_cada_100_mil = (df['nue_casosconf']/df['total_pop'])
df['casos_cada_100_mil'] = casos_cada_100_mil
df
# Out:
#       total_pop       fecha         provincia  tot_casosconf  nue_casosconf  \
# 0      13827203   5/03/2020      Buenos Aires              2              1
# 1      13827203   8/03/2020      Buenos Aires             10              8
# 2      13827203  10/03/2020      Buenos Aires             20              1
# 3      13827203  11/03/2020      Buenos Aires             22              1
# 4      13827203  13/03/2020      Buenos Aires             34              1
# ...         ...         ...               ...            ...            ...
# 1891     127205   6/07/2020  Tierra del Fuego          80447              0
# 1892     127205   7/07/2020  Tierra del Fuego          83426              0
# 1893     127205   8/07/2020  Tierra del Fuego          87029              0
# 1894     127205   9/07/2020  Tierra del Fuego          90692              1
# 1895     127205  10/07/2020  Tierra del Fuego          94058              0
#
#       tot_fallecidos  casos_cada_100_mil
# ...

# %% [markdown]
# ### 3. Calculo la cantidad de csos por provincia

# %%
#Calcular la cantidad de casos por provincia
group_a = df.groupby('provincia')

tot_casos_p = []
for key, item in group_a:
    tot_casos_p.append({"provincia":key, "total_casos":item['nue_casosconf'].sum(), "penetracion":item['casos_cada_100_mil'].sum()})

# %% [markdown]
# ### 4. Creo una lista de diccionario que contenga los datos para graficar.

# %%
bsas_caba = tot_casos_p[0]['total_casos']+tot_casos_p[0]['total_casos']
bsas_caba_p = tot_casos_p[0]['penetracion']+tot_casos_p[0]['penetracion']
tot_casos_p.append({'provincia': 'Buenos Aires CABA', 'total_casos':bsas_caba, 'penetracion':bsas_caba_p})
tot_casos_p
# Out:
# [{'provincia': 'Buenos Aires',
#   'total_casos': 49914,
#   'penetracion': 0.0036098406886772402},
#  {'provincia': 'CABA',
#   'total_casos': 36528,
#   'penetracion': 0.01315784734044201},
#  {'provincia': 'Catamarca',
#   'total_casos': 38,
#   'penetracion': 0.00010330915536609504},
#  {'provincia': 'Chaco',
#   'total_casos': 2496,
#   'penetracion': 0.0023652961026629483},
#  {'provincia': 'Chubut',
#   'total_casos': 196,
#   'penetracion': 0.0003166428107542238},
#  {'provincia': 'Corrientes',
#   'total_casos': 125,
#   'penetracion': 0.0001259325303875196},
#  {'provincia': 'Córdoba',
#   'total_casos': 852,
#   'penetracion': 0.0002838623267715158},
#  {'provincia': 'Entre Ríos',
#   'total_casos': 401,
#   'penetracion': 0.000324435231886239},
#  {'provincia': 'Formosa',
#   'total_casos': 75,
#   'penetracion': 0.00014146619335222066},
#  {'provincia': 'Jujuy',
#   'total_casos': 335,
#   'penetracion': 0.00038044706504963415},
#  {'provincia': 'La Pampa',
# ...

# %% [markdown]
# ### 5. Creo una funcion que defina el color del circulo

# %%
def definir_color(valor):
    color =""
    if valor > 0.001 :
        color = "#FF0000"
    if valor < 0.001 and valor > 0.0001:
        color = "#FF8000"
    if valor < 0.0001:
        color = "#FFFF00"
    if valor == 0.0:
        color = "#00FF00"
    
    return color

# %% [markdown]
# ### 6. Grafico el mapa

# %%
mapa_argentina = folium.Map(
    location=[-38.416097, -63.616672],
    zoom_start=4.5)

folium.CircleMarker(    
    location=[-54.275299, -67.479854],
    radius=(tot_casos_p[22]['total_casos']*50)/2496,
    popup='Tierra del Fuego 154',
    color=definir_color(tot_casos_p[22]['penetracion']),
    fill=True,
    fill_color=definir_color(tot_casos_p[22]['penetracion']),
).add_to(mapa_argentina)

folium.CircleMarker(    
    location=[-48.948193, -70.183064],
    radius=(tot_casos_p[19]['total_casos']*50)/2496,
    popup='Santa Cruz 61',
    color=definir_color(tot_casos_p[19]['penetracion']),
    fill=True,
    fill_color=definir_color(tot_casos_p[19]['penetracion']),
).add_to(mapa_argentina)

folium.CircleMarker(    
    location=[-43.585344, -68.936292],
    radius= (tot_casos_p[4]['total_casos']*50)/2496,
    popup='Chubut 196',
    color= definir_color(tot_casos_p[4]['penetracion']),
    fill=True,
    fill_color=definir_color(tot_casos_p[4]['penetracion']),
).add_to(mapa_argentina)

folium.CircleMarker(    
    location=[-40.408387, -67.228228],
    radius=(tot_casos_p[15]['total_casos']*50)/2496,
    popup='Rio Negro 1057',
    color=definir_color(tot_casos_p[15]['penetracion']),
    fill=True,
    fill_color=definir_color(tot_casos_p[15]['penetracion']),
).add_to(mapa_argentina)

folium.CircleMarker(    
    location=[-38.646009, -69.874159],
    radius=(tot_casos_p[14]['total_casos']*50)/2496,
    popup='Neuquen 663',
    color=definir_color(tot_casos_p[14]['penetracion']),
    fill=True,
    fill_color=definir_color(tot_casos_p[14]['penetracion']),
).add_to(mapa_argentina)

folium.CircleMarker(    
    location=[-36.973718, -65.758544],
    radius=(tot_casos_p[10]['total_casos']*50)/2496,
    popup='La Pampa 7',
    color=definir_color(tot_casos_p[10]['penetracion']),
    fill=True,
    fill_color=definir_color(tot_casos_p[10]['penetracion']),
).add_to(mapa_argentina)

folium.CircleMarker(    
    location=[-37.004852, -58.554476],
    radius=90,
    popup='Buenos Aires 99828',
    color=definir_color(tot_casos_p[24]['penetracion']),
    fill=True,
    fill_color=definir_color(tot_casos_p[24]['penetracion']),
).add_to(mapa_argentina)

folium.CircleMarker(    
    location=[-35.145944, -69.280002],
    radius=(tot_casos_p[12]['total_casos']*50)/2496,
    popup='Mendoza 267',
    color=definir_color(tot_casos_p[12]['penetracion']),
    fill=True,
    fill_color=definir_color(tot_casos_p[12]['penetracion']),
).add_to(mapa_argentina)

folium.CircleMarker(    
    location=[-35.015911, -65.976775],
    radius=(tot_casos_p[18]['total_casos']*50)/2496,
    popup='San Luis 12',
    color=definir_color(tot_casos_p[18]['penetracion']),
    fill=True,
    fill_color=definir_color(tot_casos_p[18]['penetracion']),
).add_to(mapa_argentina)

folium.CircleMarker(    
    location=[-32.478953, -63.653217],
    radius=(tot_casos_p[6]['total_casos']*50)/2496,
    popup='Cordoba 852',
    color=definir_color(tot_casos_p[6]['penetracion']),
    fill=True,
    fill_color= definir_color(tot_casos_p[6]['penetracion']),
).add_to(mapa_argentina)

folium.CircleMarker(    
    location=[-30.680598, -61.056876],
    radius=(tot_casos_p[20]['total_casos']*50)/2496,
    popup='Santa Fé 486',
    color=definir_color(tot_casos_p[20]['penetracion']),
    fill=True,
    fill_color=definir_color(tot_casos_p[20]['penetracion']),
).add_to(mapa_argentina)

folium.CircleMarker(    
    location=[-32.047052, -59.368277],
    radius=(tot_casos_p[7]['total_casos']*50)/2496,
    popup='Entre Rios 401',
    color=definir_color(tot_casos_p[7]['penetracion']),
    fill=True,
    fill_color=definir_color(tot_casos_p[7]['penetracion']),
).add_to(mapa_argentina)

folium.CircleMarker(    
    location=[-30.802558, -69.227872],
    radius=(tot_casos_p[17]['total_casos']*50)/2496,
    popup='San Juan 9',
    color=definir_color(tot_casos_p[17]['penetracion']),
    fill=True,
    fill_color=definir_color(tot_casos_p[17]['penetracion']),
).add_to(mapa_argentina)

folium.CircleMarker(    
    location=[-29.908659, -66.945558],
    radius=(tot_casos_p[11]['total_casos']*50)/2496,
    popup='La Rioja 131',
    color=definir_color(tot_casos_p[11]['penetracion']),
    fill=True,
    fill_color=definir_color(tot_casos_p[11]['penetracion']),
).add_to(mapa_argentina)

folium.CircleMarker(    
    location=[-27.232314, -67.268749],
    radius=(tot_casos_p[2]['total_casos']*50)/2496,
    popup='Catamarca 38',
    color=definir_color(tot_casos_p[2]['penetracion']),
    fill=True,
    fill_color=definir_color(tot_casos_p[2]['penetracion']),
).add_to(mapa_argentina)

folium.CircleMarker(    
    location=[-28.238612, -64.139401],
    radius=(tot_casos_p[21]['total_casos']*50)/2496,
    popup='Santiago del Estero 36',
    color=definir_color(tot_casos_p[21]['penetracion']),
    fill=True,
    fill_color=definir_color(tot_casos_p[21]['penetracion']),
).add_to(mapa_argentina)

folium.CircleMarker(    
    location=[-26.628999, -60.528478],
    radius=((tot_casos_p[3]['total_casos']*50)/2496)/1.5,
    popup='Chaco 2496',
    color=definir_color(tot_casos_p[3]['penetracion']),
    fill=True,
    fill_color=definir_color(tot_casos_p[3]['penetracion']),
).add_to(mapa_argentina)

folium.CircleMarker(    
    location=[-29.141644, -57.958176],
    radius=(tot_casos_p[5]['total_casos']*50)/2496,
    popup='Corrientes 125',
    color=definir_color(tot_casos_p[5]['penetracion']),
    fill=True,
    fill_color=definir_color(tot_casos_p[5]['penetracion']),
).add_to(mapa_argentina)

folium.CircleMarker(    
    location=[-24.206536, -61.147321],
    radius=(tot_casos_p[8]['total_casos']*50)/2496,
    popup='Formosa 75',
    color=definir_color(tot_casos_p[8]['penetracion']),
    fill=True,
    fill_color=definir_color(tot_casos_p[8]['penetracion']),
).add_to(mapa_argentina)

folium.CircleMarker(    
    location=[-27.236447, -65.474734],
    radius=(tot_casos_p[23]['total_casos']*50)/2496,
    popup='Tucuman 89',
    color=definir_color(tot_casos_p[23]['penetracion']),
    fill=True,
    fill_color=definir_color(tot_casos_p[23]['penetracion']),
).add_to(mapa_argentina)

folium.CircleMarker(    
    location=[-25.215860, -65.085952],
    radius=(tot_casos_p[16]['total_casos']*50)/2496,
    popup='Salta 86',
    color=definir_color(tot_casos_p[16]['penetracion']),
    fill=True,
    fill_color=definir_color(tot_casos_p[16]['penetracion']),
).add_to(mapa_argentina)

folium.CircleMarker(    
    location=[-27.096171, -54.655520],
    radius=(tot_casos_p[13]['total_casos']*50)/2496,
    popup='Misiones 42',
    color=definir_color(tot_casos_p[13]['penetracion']),
    fill=True,
    fill_color=definir_color(tot_casos_p[13]['penetracion']),
).add_to(mapa_argentina)

folium.CircleMarker(    
    location=[-22.839600, -65.851578],
    radius=(tot_casos_p[9]['total_casos']*50)/2496,
    popup='Jujuy 335',
    color=definir_color(tot_casos_p[9]['penetracion']),
    fill=True,
    fill_color=definir_color(tot_casos_p[9]['penetracion']),
).add_to(mapa_argentina)

folium.CustomIcon(
    icon_image='image.png',
    icon_size = 20
).add_to(mapa_argentina)

mapa_argentina
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <img src="image.png">
